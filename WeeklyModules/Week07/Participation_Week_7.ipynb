# %% [markdown]
# Use Google Colabs and Python to create a bar chart of yearly sales from the Internet Sales Data Set

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
sales = pd.read_csv('/content/drive/MyDrive/MSSP607/InternetSales.csv', encoding='latin-1')

# Convert 'OrderDateKey' to string and then to datetime objects
sales['OrderDate'] = pd.to_datetime(sales['OrderDateKey'].astype(str))

# Extract the year
sales['Year'] = sales['OrderDate'].dt.year
# Out:
# /tmp/ipython-input-3163929365.py:2: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   sales = pd.read_csv('/content/drive/MyDrive/MSSP607/InternetSales.csv', encoding='latin-1')

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
print(yearly_sales,Year)
# Out:
# Year
# 2010    4.342104e+04
# 2011    7.075526e+06
# 2012    5.842485e+06
# 2013    1.635155e+07
# 2014    4.569472e+04
# Name: SalesAmount, dtype: float64 0        2011
# 1        2013
# 2        2013
# 3        2013
# 4        2013
#          ...
# 60393    2013
# 60394    2013
# 60395    2011
# 60396    2012
# 60397    2012
# Name: Year, Length: 60398, dtype: int32

# %%
#group the salesamount by years
yearly_sales = sales.groupby('Year')['SalesAmount'].sum()
print(yearly_sales)
# Out:
# Year
# 2010    4.342104e+04
# 2011    7.075526e+06
# 2012    5.842485e+06
# 2013    1.635155e+07
# 2014    4.569472e+04
# Name: SalesAmount, dtype: float64

# %%
plt.figure(figsize=(10,6))
yearly_sales.plot.bar()
plt.title('Yearly Sales')
plt.xlabel('Year')
plt.ylabel('Sales Amount')
plt.show()
